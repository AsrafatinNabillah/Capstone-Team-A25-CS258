# %%
import pandas as pd

# %%
df = pd.read_csv('data/rfm_clustered.csv')

# %%
df.head(50)
# Out:
#     Recency  Frequency  Monetary  Cluster      pca1      pca2  \
# 0        75          5   2019.40        2  1.096278  0.391824
# 1        19          4   4428.69        2  1.776075 -0.196812
# 2       310          1    334.40        0 -1.435089  0.086629
# 3       375          1    300.93        0 -1.554185  0.160955
# 4        36         10   2849.84        2  2.125307  0.363466
# 5       204          2    406.76        0 -0.786876  0.093321
# 6       232          1   1079.40        1 -0.709240  0.333915
# 7       214          2    947.61        1 -0.347141  0.422691
# 8         2          5   3887.07        2  2.511877 -1.279183
# 9        52          8   4252.89        2  2.022177  0.627699
# 10      287          4    511.25        1 -0.264295  0.605079
# 11      110          2    552.00        1 -0.420869 -0.159461
# 12        8          4   1313.10        3  1.383156 -1.101003
# 13      291          2    641.38        1 -0.658025  0.463967
# ...
